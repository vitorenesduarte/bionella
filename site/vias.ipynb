# %% [markdown]
# # Vias da *Legionella Pneumophila subsp. pneumophila str. Philadelphia 1*

# %% [markdown]
# De forma a compreender as funções dos vários genes que constituem a nossa parte do genoma da bactéria, foi utilizada a base de dados KEGG (http://www.genome.jp/kegg/) para construir uma tabela com os seguintes campos:
#
# •	__Locus Tag__
#
# •	__EC number__
#
# •	__Kegg Orthology__
#
# •	__Kegg Pathways__

# %%
import os, sys, inspect, csv
import pandas as pd
from IPython.core.display import display, HTML

def import_modules():
    """
    Importar os módulos que desenvolvemos neste trabalho.
    """
    current_dir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
    parent_dir = os.path.dirname(current_dir)
    sys.path.insert(0, parent_dir)

def pretty_print_list(l):
    html = "<ul>"
    for e in l:
        html += "<li>"
        html += "<strong>id:</strong> " + str(e["id"]) + " | "
        html += "<strong>descrição:</strong> " + str(e["desc"])
        html += "</li>"
    html += "</ul>"
    return html    
    
def main():
    import_modules()
    import util.rw as rw
    
    # mostra todas as linhas
    pd.options.display.max_rows = 250
    
    # não truncar informação
    pd.set_option('display.max_colwidth', -1)
    
    KEGG = rw.read_json("files/KEGG.json")
    df = pd.DataFrame(KEGG).transpose()
    
    df["Orthology"] = df["Orthology"].apply(pretty_print_list)
    df["Pathways"] = df["Pathways"].apply(pretty_print_list)
    display(HTML(df.to_html(escape=False)))

main()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>EC_number</th>
#       <th>Orthology</th>
#       <th>Pathways</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>lpg0232</th>
#       <td></td>
#       <td><ul><li><strong>id:</strong> K09823 | <strong>descrição:</strong> Fur family transcriptional regulator, zinc uptake regulator</li></ul></td>
#       <td><ul><li><strong>id:</strong> lpn02024 | <strong>descrição:</strong> Quorum sensing</li></ul></td>
#     </tr>
#     <tr>
#       <th>lpg0233</th>
#       <td>[EC:4.1.1.7]</td>
#       <td><ul><li><strong>id:</strong> K01576 | <strong>descrição:</strong> benzoylformate decarboxylase</li></ul></td>
#       <td><ul><li><strong>id:</strong> lpn00627 | <strong>descrição:</strong> Aminobenzoate degradation</li><li><strong>id:</strong> lpn01120 | <strong>descrição:</strong> Microbial metabolism in diverse environments</li></ul></td>
#     </tr>
#     <tr>
#       <th>lpg0238</th>
#       <td>[EC:1.2.1.8]</td>
#       <td><ul><li><strong>id:</strong> K00130 | <strong>descrição:</strong> betaine-aldehyde dehydrogenase</li></ul></td>
#       <td><ul><li><strong>id:</strong> lpn00260 | <strong>descrição:</strong> Glycine, serine and threonine metabolism</li><li><strong>id:</strong> lpn01100 | <strong>descrição:</strong> Metabolic pathways</li></ul></td>
#     </tr>
#     <tr>
#       <th>lpg0239</th>
#       <td>[EC:2.6.1.19|2.6.1.22]</td>
#       <td><ul><li><strong>id:</strong> K07250 | <strong>descrição:</strong> 4-aminobutyrate aminotransferase / (S)-3-amino-2-methylpropionate transaminase</li></ul></td>
#       <td><ul><li><strong>id:</strong> lpn00250 | <strong>descrição:</strong> Alanine, aspartate and glutamate metabolism</li><li><strong>id:</strong> lpn00280 | <strong>descrição:</strong> Valine, leucine and isoleucine degradation</li><li><strong>id:</strong> lpn00410 | <strong>descrição:</strong> beta-Alanine metabolism</li><li><strong>id:</strong> lpn00640 | <strong>descrição:</strong> Propanoate metabolism</li><li><strong>id:</strong> lpn00650 | <strong>descrição:</strong> Butanoate metabolism</li><li><strong>id:</strong> lpn01100 | <strong>descrição:</strong> Metabolic pathways</li><li><strong>id:</strong> lpn01120 | <strong>descrição:</strong> Microbial metabolism in diverse environments</li></ul></td>
#     </tr>
#     <tr>
#       <th>lpg0241</th>
#       <td>[EC:3.5.1.2]</td>
#       <td><ul><li><strong>id:</strong> K01425 | <strong>descrição:</strong> glutaminase</li></ul></td>
#       <td><ul><li><strong>id:</strong> lpn00220 | <strong>descrição:</strong> Arginine biosynthesis</li><li><strong>id:</strong> lpn00250 | <strong>descrição:</strong> Alanine, aspartate and glutamate metabolism</li><li><strong>id:</strong> lpn00471 | <strong>descrição:</strong> D-Glutamine and D-glutamate metabolism</li><li><strong>id:</strong> lpn01100 | <strong>descrição:</strong> Metabolic pathways</li></ul></td>
#     </tr>
#     <tr>
#       <th>lpg0242</th>
#       <td>[EC:1.1.1.95]</td>
#       <td><ul><li><strong>id:</strong> K00058 | <strong>descrição:</strong> D-3-phosphoglycerate dehydrogenase</li></ul></td>
#       <td><ul><li><strong>id:</strong> lpn00260 | <strong>descrição:</strong> Glycine, serine and threonine metabolism</li><li><strong>id:</strong> lpn00680 | <strong>descrição:</strong> Methane metabolism</li><li><strong>id:</strong> lpn01100 | <strong>descrição:</strong> Metabolic pathways</li><li><strong>id:</strong> lpn01120 | <strong>descrição:</strong> Microbial metabolism in diverse environments</li><li><strong>id:</strong> lpn01130 | <strong>descrição:</strong> Biosynthesis of antibiotics</li><li><strong>id:</strong> lpn01200 | <strong>descrição:</strong> Carbon metabolism</li><li><strong>id:</strong> lpn01230 | <strong>descrição:</strong> Biosynthesis of amino acids</li></ul></td>
#     </tr>
#     <tr>
#       <th>lpg0245</th>
#       <td>[EC:1.4.1.2]</td>
#       <td><ul><li><strong>id:</strong> K15371 | <strong>descrição:</strong> glutamate dehydrogenase</li></ul></td>
#       <td><ul><li><strong>id:</strong> lpn00220 | <strong>descrição:</strong> Arginine biosynthesis</li><li><strong>id:</strong> lpn00250 | <strong>descrição:</strong> Alanine, aspartate and glutamate metabolism</li><li><strong>id:</strong> lpn00430 | <strong>descrição:</strong> Taurine and hypotaurine metabolism</li><li><strong>id:</strong> lpn00910 | <strong>descrição:</strong> Nitrogen metabolism</li></ul></td>
#     </tr>
#     <tr>
#       <th>lpg0248</th>
#       <td>[EC:1.20.4.1]</td>
#       <td><ul><li><strong>id:</strong> K00537 | <strong>descrição:</strong> arsenate reductase</li></ul></td>
#       <td><ul></ul></td>
#     </tr>
#     <tr>
#       <th>lpg0249</th>
#       <td>[EC:1.14.19.1]</td>
#       <td><ul><li><strong>id:</strong> K00507 | <strong>descrição:</strong> stearoyl-CoA desaturase (Delta-9 desaturase)</li></ul></td>
#       <td><ul><li><strong>id:</strong> lpn01040 | <strong>descrição:</strong> Biosynthesis of unsaturated fatty acids</li><li><strong>id:</strong> lpn01212 | <strong>descrição:</strong> Fatty acid metabolism</li></ul></td>
#     </tr>
#     <tr>
#       <th>lpg0250</th>
#       <td>[EC:3.6.4.13]</td>
#       <td><ul><li><strong>id:</strong> K11927 | <strong>descrição:</strong> ATP-dependent RNA helicase RhlE</li></ul></td>
#       <td><ul><li><strong>id:</strong> lpn03018 | <strong>descrição:</strong> RNA degradation</li></ul></td>
#     </tr>
#     <tr>
#       <th>lpg0252</th>
#       <td></td>
#       <td><ul><li><strong>id:</strong> K09125 | <strong>descrição:</strong> uncharacterized protein</li></ul></td>
#       <td><ul></ul></td>
#     </tr>
#     <tr>
#       <th>lpg0262</th>
#       <td>[EC:2.7.7.7]</td>
#       <td><ul><li><strong>id:</strong> K02334 | <strong>descrição:</strong> DNA polymerase bacteriophage-type</li></ul></td>
#       <td><ul></ul></td>
#     </tr>
#     <tr>
#       <th>lpg0263</th>
#       <td></td>
#       <td><ul><li><strong>id:</strong> K06902 | <strong>descrição:</strong> MFS transporter, UMF1 family</li></ul></td>
#       <td><ul></ul></td>
#     </tr>
#     <tr>
#       <th>lpg0268</th>
#       <td></td>
#       <td><ul><li><strong>id:</strong> K07023 | <strong>descrição:</strong> putative hydrolases of HD superfamily</li></ul></td>
#       <td><ul></ul></td>
#     </tr>
#     <tr>
#       <th>lpg0269</th>
#       <td></td>
#       <td><ul><li><strong>id:</strong> K06915 | <strong>descrição:</strong> uncharacterized protein</li></ul></td>
#       <td><ul></ul></td>
#     </tr>
#     <tr>
#       <th>lpg0270</th>
#       <td>[EC:6.3.4.21]</td>
#       <td><ul><li><strong>id:</strong> K00763 | <strong>descrição:</strong> nicotinate phosphoribosyltransferase</li></ul></td>
#       <td><ul><li><strong>id:</strong> lpn00760 | <strong>descrição:</strong> Nicotinate and nicotinamide metabolism</li><li><strong>id:</strong> lpn01100 | <strong>descrição:</strong> Metabolic pathways</li></ul></td>
#     </tr>
#     <tr>
#       <th>lpg0271</th>
#       <td>[EC:3.5.1.19| 3.5.1.-]</td>
#       <td><ul><li><strong>id:</strong> K08281 | <strong>descrição:</strong> nicotinamidase/pyrazinamidase</li></ul></td>
#       <td><ul><li><strong>id:</strong> lpn00760 | <strong>descrição:</strong> Nicotinate and nicotinamide metabolism</li><li><strong>id:</strong> lpn01100 | <strong>descrição:</strong> Metabolic pathways</li></ul></td>
#     </tr>
#     <tr>
#       <th>lpg0275</th>
#       <td></td>
#       <td><ul><li><strong>id:</strong> K15487 | <strong>descrição:</strong> effector protein SdbA</li></ul></td>
#       <td><ul><li><strong>id:</strong> lpn05134 | <strong>descrição:</strong> Legionellosis</li></ul></td>
#     </tr>
#     <tr>
#       <th>lpg0283</th>
#       <td>[EC:1.2.1.2]</td>
#       <td><ul><li><strong>id:</strong> K00122 | <strong>descrição:</strong> formate dehydrogenase</li></ul></td>
#       <td><ul><li><strong>id:</strong> lpn00630 | <strong>descrição:</strong> Glyoxylate and dicarboxylate metabolism</li><li><strong>id:</strong> lpn00680 | <strong>descrição:</strong> Methane metabolism</li><li><strong>id:</strong> lpn01100 | <strong>descrição:</strong> Metabolic pathways</li><li><strong>id:</strong> l

# %% [markdown]
# Em baixo apresentamos a via metabólica da bactéria (__figura 1__) e a via responsável pela infeção provocada pela mesma (__figura 2__). Estas representam todo o genoma, uma vez que não faria sentido utilizar apenas as proteínas da zona do genoma em estudo, pois não fazem parte desta zona as proteínas necessárias para completar pelo menos uma das vias metabólicas ou infeciosas da bactéria.

# %% [markdown]
# ![Metabolismo](img/ViaMetabolica.png)
# __Figura1 - __ Rede Metabólica da *Legionella Pneumophila susbp. pneumophila str. Philadelphia 1*.

# %% [markdown]
# ![Infecao](img/ViaInfec.png)
# __Figura 2 - __ Via responsável pela infeção provocada pela *Legionella Pneumophila susbp. pneumophila str. Philadelphia 1*.

# %% [markdown]
# [Índice](index.html) | [Anterior](alignments.html) | [Seguinte](transporters.html)
