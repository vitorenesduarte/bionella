# %% [markdown]
# ## Vias da Bactéria

# %% [markdown]
# ![Metabolismo](img/ViaMetabolica.png)
# __Figura1 - __ Rede Metabólica da *Legionella Pneumophila susbp. pneumophila str. Philadelphia 1*.

# %% [markdown]
# ![Infecao](img/ViaInfec.png)
# __Figura 2 - __ Via responsável pela infeção provocada pela *Legionella Pneumophila susbp. pneumophila str. Philadelphia 1*.

# %%
import pandas as pd

df = pd.read_csv("files/KEGG.csv", sep=";")
df
# Out:
#     Locus Tag                 EC number Kegg orthology  \
# 0    lpg0232   NaN                       K09823
# 1    lpg0233   [EC:4.1.1.7]              K01576
# 2    NaN       NaN                       NaN
# 3    lpg0238   [EC:1.2.1.8]              K00130
# 4    NaN       NaN                       NaN
# 5    lpg0239   [EC:2.6.1.19|2.6.1.22]    K07250
# 6    NaN       NaN                       NaN
# 7    NaN       NaN                       NaN
# 8    NaN       NaN                       NaN
# 9    NaN       NaN                       NaN
# 10   NaN       NaN                       NaN
# 11   NaN       NaN                       NaN
# 12   lpg0241   [EC:3.5.1.2]              K01425
# 13   NaN       NaN                       NaN
# 14   NaN       NaN                       NaN
# 15   NaN       NaN                       NaN
# 16   lpg0242   [EC:1.1.1.95]             K00058
# 17   NaN       NaN                       NaN
# 18   NaN       NaN                       NaN
# 19   NaN       NaN                       NaN
# 20   NaN       NaN                       NaN
# 21   NaN       NaN                       NaN
# 22   NaN       NaN                       NaN
# 23   lpg0245   [EC:1.4.1.2]              K15371
# 24   NaN       NaN                       NaN
# 25   NaN       NaN                       NaN
# 26   NaN       NaN                       NaN
# 27   lpg0248    [EC:1.20.4.1]            K00537
# 28   lpg0249   [EC:1.14.19.1]            K00507
# 29   NaN       NaN                       NaN
# ..   ...       ...                       ...
# 214  lpg0426   NaN                       K03704
# 215  lpg0441   NaN                       K12222
# 216  lpg0442   NaN                       K12221
# 217  lpg0443   NaN                       K12220
# 218  lpg0444   NaN                       K12219
# 219  lpg0445   NaN                       K12218
# 220  lpg0446   NaN                       K12217
# 221  lpg0447   NaN                       K12216
# 222  lpg0448   NaN                       K12215
# 223  lpg0449   NaN                       K12214
# 224  lpg0450   NaN                       K12213
# 225  lpg0451   NaN                       K12209
# 226  lpg0452   NaN                       K12211
# 227  lpg0453   NaN                       K12207
# 228  lpg0454   NaN                       K12208
# 229  lpg0455   NaN                       K12212
# 230  lpg0456   NaN                       K12206
# 231  lpg0457   NaN                       K12226
# 232  lpg0458   NaN                       K12210
# 233  lpg0460   [EC:2.1.2.3 |  3.5.4.10]  K00602
# 234  NaN       NaN                       NaN
# 235  NaN       NaN                       NaN
# 236  NaN       NaN                       NaN
# 237  NaN       NaN                       NaN
# 238  lpg0461   [EC:2.1.1.-]              K02687
# 239  lpg0462   [EC:6.4.1.2 | 6.3.4.14]   K01961
# 240  lpg_3050  NaN                       K02965
# 241  NaN       NaN                       NaN
# 242  NaN       NaN                       NaN
# 243  NaN       NaN                       NaN
#
#                                                                          Unnamed: 3  \
# 0    Fur family transcriptional regulator, zinc uptake regulator
# 1    benzoylformate decarboxylase
# 2    NaN
# 3    betaine-aldehyde dehydrogenase
# 4    NaN
# 5    4-aminobutyrate aminotransferase / (S)-3-amino-2-methylpropionate transaminase
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   glutaminase
# 13   NaN
# 14   NaN
# 15   NaN
# 16   D-3-phosphoglycerate dehydrogenase
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   glutamate dehydrogenase
# 24   NaN
# 25   NaN
# 26   NaN
# 27   arsenate reductase
# 28   stearoyl-CoA desaturase (Delta-9 desaturase)
# 29   NaN
# ..   ...
# 214  cold shock protein (beta-ribbon, CspA family)
# 215  intracellular multiplication protein IcmT
# 216  intracellular multiplication protein IcmS
# 217  intracellular multiplication protein IcmR
# 218  intracellular multiplication protein IcmQ
# 219  intracellular multiplication protein IcmP
# 220  intracellular multiplication protein IcmO
# 221  intracellular multiplication protein IcmN
# 222  intracellular multiplication protein IcmM
# 223  intracellular multiplication protein IcmL
# 224  intracellular multiplication protein IcmK
# 225  intracellular multiplication protein IcmE
# 226  intracellular multiplication protein IcmG
# 227  intracellular multiplication protein IcmC
# 228  intracellular multiplication protein IcmD
# 229  intracellular multiplication protein IcmJ
# 230  intracellular multiplication protein IcmB
# 231  proline/betaine transport protein TphA
# 232  intracellular multiplication protein IcmF
# 233  phosphoribosylaminoimidazolecarboxamide formyltransferase / IMP cyclohydrolase
# 234  NaN
# 235  NaN
# 236  NaN
# 237  NaN
# 238  ribosomal protein L11 methyltransferase
# 239  acetyl-CoA carboxylase, biotin carboxylase subunit
# 240  small subunit ribosomal protein S19
# 241  NaN
# 242  NaN
# 243  NaN
#
#      Pathways                                    Unnamed: 5  Unnamed: 6  \
# 0    lpn02024  Quorum sensing                               NaN
# 1    lpn00627  Aminobenzoate degradation                    NaN
# 2    lpn01120  Microbial metabolism in diverse environments NaN
# 3    lpn00260  Glycine, serine and threonine metabolism     NaN
# 4    lpn01100  Metabolic pathways                           NaN
# 5    lpn00250  Alanine, aspartate and glutamate metabolism  NaN
# 6    lpn00280  Valine, leucine and isoleucine degradation   NaN
# 7    lpn00410  beta-Alanine metabolism                      NaN
# 8    lpn00640  Propanoate metabolism                        NaN
# 9    lpn00650  Butanoate metabolism                         NaN
# 10   lpn01100  Metabolic pathways                           NaN
# 11   lpn01120  Microbial metabolism in diverse environments NaN
# 12   lpn00220  Arginine biosynthesis                        NaN
# 13   lpn00250  Alanine, aspartate and glutamate metabolism  NaN
# 14   lpn00471  D-Glutamine and D-glutamate metabolism       NaN
# 15   lpn01100  Metabolic pathways                           NaN
# 16   lpn00260  Glycine, serine and threonine metabolism     NaN
# 17   lpn00680  Methane metabolism                           NaN
# 18   lpn01100  Metabolic pathways                           NaN
# 19   lpn01120  Microbial metabolism in diverse environments NaN
# 20   lpn01130  Biosynthesis of antibiotics                  NaN
# 21   lpn01200  Carbon metabolism                            NaN
# 22   lpn01230  Biosynthesis of amino acids                  NaN
# 23   lpn00220  Arginine biosynthesis                        NaN
# 24   lpn00250  Alanine, aspartate and glutamate metabolism  NaN
# 25   lpn00430  Taurine and hypotaurine metabolism           NaN
# 26   lpn00910  Nitrogen metabolism                          NaN
# 27   NaN       NaN                                          NaN
# 28   lpn01040  Biosynthesis of unsaturated fatty acids      NaN
# 29   lpn01212  Fatty acid metabolism                        NaN
# ..        ...                    ...                         ..
# 214  NaN       NaN                                          NaN
# 215  NaN       NaN                                          NaN
# 216  NaN       NaN                                          NaN
# 217  NaN       NaN                                          NaN
# 218  NaN       NaN                                          NaN
# 219  NaN       NaN                                          NaN
# 220  NaN       NaN                                          NaN
# 221  NaN       NaN                                          NaN
# 222  NaN       NaN                                          NaN
# 223  NaN       NaN                                          NaN
# 224  NaN       NaN                                          NaN
# 225  NaN       NaN                                          NaN
# 226  NaN       NaN                                          NaN
# 227  NaN       NaN                                          NaN
# 228  NaN       NaN                                          NaN
# 229  NaN       NaN                                          NaN
# 230  NaN       NaN                                          NaN
# 231  NaN       NaN                                          NaN
# 232  NaN       NaN                                          NaN
# 233  lpn00230  Purine metabolism                            NaN
# 234  lpn00670  One carbon pool by folate                    NaN
# 235  lpn01100  Metabolic pathways                           NaN
# 236  lpn01110  Biosynthesis of secondary metabolites        NaN
# 237  lpn01130  Biosynthesis of antibiotics                  NaN
# 238  NaN       NaN                                          NaN
# 239  NaN       NaN                                          NaN
# 240  lpn03010  Ribosome                                     NaN
# 241  NaN       NaN                                          NaN
# 242  NaN       NaN                                          NaN
# 243  NaN       NaN                                          NaN
#
#      Unnamed: 7
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# 10  NaN
# 11  NaN
# 12  NaN
# 13  NaN
# 14  NaN
# 15  NaN
# 16  NaN
# 17  NaN
# 18  NaN
# 19  NaN
# 20  NaN
# 21  NaN
# 22  NaN
# 23  NaN
# 24  NaN
# 25  NaN
# 26  NaN
# 27  NaN
# 28  NaN
# 29  NaN
# ..   ..
# 214 NaN
# 215 NaN
# 216 NaN
# 217 NaN
# 218 NaN
# 219 NaN
# 220 NaN
# 221 NaN
# 222 NaN
# 223 NaN
# 224 NaN
# 225 NaN
# 226 NaN
# 227 NaN
# 228 NaN
# 229 NaN
# 230 NaN
# 231 NaN
# 232 NaN
# 233 NaN
# 234 NaN
# 235 NaN
# 236 NaN
# 237 NaN
# 238 NaN
# 239 NaN
# 240 NaN
# 241 NaN
# 242 NaN
# 243 NaN
#
# [244 rows x 8 columns]
